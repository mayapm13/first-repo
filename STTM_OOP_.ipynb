# %%
# !pip install jsonpath_ng
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jsonpath_ng
#   Downloading jsonpath_ng-1.5.3-py3-none-any.whl (29 kB)
# Collecting ply (from jsonpath_ng)
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (4.4.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (1.16.0)
# Installing collected packages: ply, jsonpath_ng
# Successfully installed jsonpath_ng-1.5.3 ply-3.11

# %%
import os
import json
import numpy as np 
import pandas as pd 
import sqlite3
import functools as ft
import matplotlib.pyplot as plt
from abc import ABC, abstractmethod
from jsonpath_ng import parse
from enum import Enum
# %matplotlib inline

# %% [markdown]
# # Source to Target Mapping - OOP Approach for Single Table

# %% [markdown]
# ### Data

# %%
Fact_df = pd.read_excel('Fact Table (1).xlsx')
Fact_df
Fact_df.to_json("Fact Table (1).json")
json_Fact_df = Fact_df.astype(str).to_dict(orient='records')
json_Fact_df
# Out:
# [{'Date': '2005-06-30', 'PatientNumber': '1', 'Age': '75', 'RoutineTest': '1'},
#  {'Date': '2005-07-08', 'PatientNumber': '1', 'Age': '75', 'RoutineTest': '1'},
#  {'Date': '2005-10-24', 'PatientNumber': '1', 'Age': '75', 'RoutineTest': '1'},
#  {'Date': '2006-01-08', 'PatientNumber': '1', 'Age': '75', 'RoutineTest': '1'},
#  {'Date': '2006-02-02', 'PatientNumber': '1', 'Age': '75', 'RoutineTest': '1'},
#  {'Date': '2006-03-13', 'PatientNumber': '1', 'Age': '75', 'RoutineTest': '1'},
#  {'Date': '2006-04-08', 'PatientNumber': '1', 'Age': '75', 'RoutineTest': '1'},
#  {'Date': '2006-04-26', 'PatientNumber': '1', 'Age': '75', 'RoutineTest': '1'},
#  {'Date': '2006-10-14', 'PatientNumber': '1', 'Age': '76', 'RoutineTest': '1'},
#  {'Date': '2007-02-02', 'PatientNumber': '1', 'Age': '76', 'RoutineTest': '1'},
#  {'Date': '2007-04-27', 'PatientNumber': '1', 'Age': '76', 'RoutineTest': '1'},
#  {'Date': '2007-09-29', 'PatientNumber': '1', 'Age': '77', 'RoutineTest': '1'},
#  {'Date': '2007-12-03', 'PatientNumber': '1', 'Age': '77', 'RoutineTest': '1'},
#  {'Date': '2008-10-31', 'PatientNumber': '1', 'Age': '78', 'RoutineTest': '1'},
#  {'Date': '2008-12-15', 'PatientNumber': '1', 'Age': '78', 'RoutineTest': '1'},
#  {'Date': '2009-08-27', 'PatientNumber': '1', 'Age': '79', 'RoutineTest': '1'},
#  {'Date': '2010-02-26', 'PatientNumber': '1', 'Age': '79', 'RoutineTest': '1'},
#  {'Date': '2010-03-29', 'PatientNumber': '1', 'Age': '79', 'RoutineTest': '1'},
#  {'Date': '2010-04-15', 'PatientNumber': '1', 'Age': '79', 'RoutineTest': '1'},
#  {'Date': '2010-05-13', 'PatientNumber': '1', 'Age': '79', 'RoutineTest': '1'},
#  {'Date': '2010-07-23', 'PatientNumber': '1', 'Age': '80', 'RoutineTest': '1'},
#  {'Date': '2010-09-08', 'PatientNumber': '1', 'Age': '80', 'RoutineTest': '1'},
#  {'Date': '2011-03-11', 'PatientNumber': '1', 'Age': '80', 'RoutineTest': '1'},
#  {'Date': '2011-04-05', 'PatientNumber': '1', 'Age': '80', 'RoutineTest': '1'},
#  {'Date': '2011-04-29', 'PatientNumber': '1', 'Age': '80', 'RoutineTest': '1'},
#  {'Date': '2011-07-18', 'PatientNumber': '1', 'Age': '81', 'RoutineTest': '1'},
#  {'Date': '2011-09-06', 'PatientNumber': '1', 'Age': '81', 'RoutineTest': '1'},
#  {'Date': '2013-01-12', 'PatientNumber': '1', 'Age': '82', 'RoutineTest': '1'},
#  {'Date': '2013-05-12', 'PatientNumber': '1', 'Age': '82', 'RoutineTest': '1'},
#  {'Date': '2014-04-07', 'PatientNumber': '1', 'Age': '83', 'RoutineTest': '1'},
#  {'Date': '2014-06-30', 'PatientNumber': '1', 'Age': '84', 'RoutineTest': '1'},
#  {'Date': '2014-07-27', 'PatientNumber': '1', 'Age': '84', 'RoutineTest': '1'},
#  {'Date': '2014-12-04', 'PatientNumber': '1', 'Age': '84', 'RoutineTest': '1'},
#  {'Date': '2015-01-24', 'PatientNumber': '1', 'Age': '84', 'RoutineTest': '1'},
#  {'Date': '2015-02-22', 'PatientNumber': '1', 'Age': '84', 'RoutineTest': '1'},
#  {'Date': '2015-04-15', 'PatientNumber': '1', 'Age': '84', 'RoutineTest': '1'},
#  {'Date': '2015-06-07', 'PatientNumber': '1', 'Age': '84', 'RoutineTest': '1'},
#  {'Date': '2015-12-22', 'PatientNumber': '1', 'Age': '85', 'RoutineTest': '1'},
#  {'Date': '2016-08-18', 'PatientNumber': '1', 'Age': '86', 'RoutineTest': '1'},
#  {'Date': '2016-09-29', 'PatientNumber': '1', 'Age': '86', 'RoutineTest': '1'},
#  {'Date': '2016-12-11', 'PatientNumber': '1', 'Age': '86', 'RoutineTest': '1'},
#  {'Date': '2016-12-17', 'PatientNumber': '1', 'Age': '86', 'RoutineTest': '1'},
#  {'Date': '2017-06-13', 'PatientNumber': '1', 'Age': '86', 'RoutineTest': '1'},
#  {'Date': '2017-07-04', 'PatientNumber': '1', 'Age': '87', 'RoutineTest': '1'},
#  {'Date': '2017-12-09', 'PatientNumber': '1', 'Age': '87', 'RoutineTest': '1'},
#  {'Date': '2017-12-19', 'PatientNumber': '1', 'Age': '87', 'RoutineTest': '1'},
#  {'Date': '2018-05-06', 'PatientNumber': '1', 'Age': '87', 'RoutineTest': '1'},
#  {'Date': '2018-05-18', 'PatientNumber': '1', 'Age': '87', 'RoutineTest': '1'},
#  {'Date': '2018-08-27', 'PatientNumber': '1', 'Age': '88', 'RoutineTest': '1'},
#  {'Date': '2018-09-26', 'PatientNumber': '1', 'Age': '88', 'RoutineTest': '1'},
#  {'Date': '2018-09-28', 'PatientNumber': '1', 'Age': '88', 'RoutineTest': '1'},
#  {'Date': '2018-10-07', 'PatientNumber': '1', 'Age': '88', 'RoutineTest': '1'},
#  {'Date': '2018-12-08', 'PatientNumber': '1', 'Age': '88', 'RoutineTest': '1'},
#  {'Date': '2019-01-19', 'PatientNumber': '1', 'Age': '88', 'RoutineTest': '1'},
#  {'Date': '2019-02-02', 'PatientNumber': '1', 'Age': '88', 'RoutineTest': '1'},
#  {'Date': '2019-03-24', 'PatientNumber': '1', 'Age': '88', 'RoutineTest': '1'},
#  {'Date': '2019-04-30', 'PatientNumber': '1', 'Age': '88', 'RoutineTest': '1'},
#  {'Date': '2019-10-21', 'PatientNumber': '1', 'Age': '75', 'RoutineTest': '1'},
#  {'Date': '
 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2013-05-19', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2013-05-23', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2013-05-27', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2013-06-03', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2013-06-05', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2013-06-09', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2013-06-21', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2013-06-25', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2013-07-03', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2013-07-19', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2013-08-05', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2013-09-11', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2013-10-13', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2013-10-22', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2013-10-26', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2013-11-22', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2013-12-03', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2013-12-19', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-01-16', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-02-02', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-02-23', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-02-25', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-03-14', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-04-05', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-04-05', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-04-19', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-04-27', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-05-09', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-05-10', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-05-11', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-05-13', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-05-18', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-05-19', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-05-25', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-06-05', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-06-05', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-06-09', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-06-20', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-07-16', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-08-08', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-08-26', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-08-31', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-09-18', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-09-22', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-10-02', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-10-05', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-10-12', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-10-15', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-10-17', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-10-20', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-11-09', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2014-11-21', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-01-23', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-04-09', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-05-16', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-05-21', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-05-31', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-06-05', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-06-08', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-06-11', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-07-06', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-07-08', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-07-14', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-07-18', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-07-27', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-08-05', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-08-10', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-09-16', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-10-01', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-10-16', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-11-11', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-11-28', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-11-30', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-12-26', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-12-27', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2015-12-29', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-01-16', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-01-27', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-01-28', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-02-06', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-03-17', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-03-29', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-04-10', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-04-21', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-04-25', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-04-30', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-05-01', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-05-10', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-05-10', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-05-15', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-05-22', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-06-03', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-06-11', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-06-28', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-07-09', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-07-19', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-07-21', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-07-25', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-07-29', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-08-18', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-09-04', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-09-21', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-10-12', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-10-22', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-12-02', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-12-07', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-12-11', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-12-26', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2016-12-29', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-01-06', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-01-13', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-02-04', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-02-10', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-02-14', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-02-15', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-02-19', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-02-20', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-02-22', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-02-23', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-03-16', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-04-11', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-04-23', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-04-27', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-05-10', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-05-27', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-06-05', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-06-18', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-06-27', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-08-01', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-08-17', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-08-18', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-08-23', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-09-02', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  {'Date': '2017-09-08', 'PatientNumber': '3', 'Age': '90', 'RoutineTest': '1'},
#  ...]

# %% [markdown]
# ###  Abstract Base Calss (ABC) for mutual methods

# %%
class Interface(ABC):

    @abstractmethod
    def get_data_by_field(self, field_name):
        """Fetch the data by given feild name """

    @abstractmethod
    def get_data_by_id(self, id):
        """Fetch the data by given ID  """

    @abstractmethod
    def get(self):
        """Fetch all data """

# %% [markdown]
# ### Transform Operations
# inherithed from Enum - class that automatic enumrate the variables

# %%
class TransformMask(Enum):
    # add here any masks you want 
    CLEAN_STRING = ".strip().lower()" 
    CAPITAL_LETTER = ".strip().lower().title()"

# %% [markdown]
# ### Database Class - Define Common Properties for Source, Target, Mapping

# %%
class Database:
    def __init__(self):
        pass

    # built-in function that creates and returns a property object
    # get data by: get_data_source_target_mapping.get(dict_key)
    @property 
    def get_data_source_target_mapping(self):
        return {
            "source": [
                {
                    "id": 1,
                    "source_field_name": "Date",
                    "source_field_mapping": "$.Date",
                    "source_field_type": "str", # use python types
                    "is_required": True,

                },
                {
                    "id": 2,
                    "source_field_name": "PatientNumber",
                    "source_field_mapping": "$.PatientNumber",
                    "source_field_type": "str",
                    "is_required": True,

                },
                {
                    "id": 3,
                    "source_field_name": "Age",
                    "source_field_mapping": "$.Age",
                    "source_field_type": "str",
                    "is_required": True,

                },
                {
                    "id": 4,
                    "source_field_name": "RoutineTest",
                    "source_field_mapping": "$.RoutineTest",
                    "source_field_type": "str",
                    "is_required": True,

                }
            ],
            "destination": [
                {
                    "id": 1,
                    "destination_field_name": "Date",
                    "destination_field_mapping": "Date",
                    "destination_field_type": "str",
                    "default_value": "n/a",
                },
                {
                    "id": 2,
                    "destination_field_name": "PatientNumber",
                    "destination_field_mapping": "PatientNumber",
                    "destination_field_type": "int",
                    "default_value": "0"
                },
                                {
                    "id": 3,
                    "destination_field_name": "Age",
                    "destination_field_mapping": "Age",
                    "destination_field_type": "int",
                    "default_value": "0"
                },
                                {
                    "id": 4,
                    "destination_field_name": "RoutineTest",
                    "destination_field_mapping": "RoutineTest",
                    "destination_field_type": "str",
                    "default_value": "0"
                }

            ],
            "transform": [ # using the Enums 
                {
                    "id": 1,
                    "transform_mask": 'CAPITAL_LETTER'
                },
                {
                    "id": 2,
                    "transform_mask": 'CLEAN_STRING'
                }
            ],
            "mapping": [
                {
                    "id": 1,
                    "mapping_source": 1,
                    "mapping_destination": 1,
                    "mapping_transform": 1
                },
                {
                    "id": 2,
                    "mapping_source": 2,
                    "mapping_destination": 2,
                },
                                {
                    "id": 3,
                    "mapping_source": 3,
                    "mapping_destination": 3,
                },
                                {
                    "id": 4,
                    "mapping_source": 4,
                    "mapping_destination": 4,
                }
            ]
        }

# %% [markdown]
# ### Source class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Source(Interface, Database):
    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("source")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id") == self.id:
                return x
        return None

# %% [markdown]
# ### Target class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Target(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("destination")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

# %% [markdown]
# ### Transform Class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Transform(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("transform", [])

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

# %% [markdown]
# ### Mapping class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Mappings(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("mapping")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

    def get_data_by_field(self, field_name):
        return None

# %% [markdown]
# ### Format Class - JSON
#
# Search the source data value inside a JSON file

# %%
class JsonQuery:
    def __init__(self, json_path, json_data):
        self.json_path = json_path
        self.json_data = json_data

    def get(self):
        jsonpath_expression = parse(self.json_path)
        match = jsonpath_expression.find(self.json_data)
        source_data_value = match[0].value
        return source_data_value

# %% [markdown]
# ### Combine it All - STTM

# %%
class STTM:
    def __init__(self, input_json):
        self.input_json = input_json
        self.mapping_instance = Mappings()
        self.source_instance = Source()
        self.destination_instance = Target()
        self.transform_instance = Transform()
        self.look_up_mask = {i.name: i.value for i in TransformMask}
        self.json_data_transformed = {}

    def _get_mapping_data(self):
        return self.mapping_instance.get

    def _get_mapping_source_data(self):
        return self.source_instance.get

    def get_transformed_data(self):

        for mappings in self._get_mapping_data():

            """fetch the source mapping """
            mapping_source_id = mappings.get("mapping_source")
            mapping_destination_id = mappings.get("mapping_destination")
            mapping_transform_id = mappings.get("mapping_transform")

            mapping_source_data = self.source_instance.get_data_by_id(id=mapping_source_id)
            transform_data = self.transform_instance.get_data_by_id(id=mapping_transform_id)

            """Fetch Source  field Name"""
            source_field_name = mapping_source_data.get("source_field_name")

            """if field given is not present incoming json """
            if source_field_name not in self.input_json.keys():
                if mapping_source_data.get("is_required"):
                    raise Exception(
                        "Alert ! Field {} is not present in JSON please FIX mappings ".format(source_field_name))
                else:
                    pass

            else:
                source_data_value = JsonQuery(
                    json_path=mapping_source_data.get("source_field_mapping"),
                    json_data=self.input_json
                ).get()

                """check the data type for source if matches with what we have """
                if mapping_source_data.get("source_field_type") != type(source_data_value).__name__:
                    if source_data_value is not None:
                        _message = (
                            "Alert ! Source Field :{} Datatype has changed from {} to {} ".format(source_field_name,
                                                                                                  mapping_source_data.get(
                                                                                                      "source_field_type"),
                                                                                                  type(
                                                                                                      source_data_value).__name__))
                        print(_message)
                        raise Exception(_message)

                """Query and fetch the Destination | target """
                destination_mappings_json_object = self.destination_instance.get_data_by_id(
                    id=mappings.get("mapping_destination"))

                destination_field_name = destination_mappings_json_object.get("destination_field_name")
                destination_field_type = destination_mappings_json_object.get("destination_field_type")

                dtypes = [str, float, list, int, set, dict]

                for dtype in dtypes:

                    """Datatype Conversion """
                    if destination_field_type == str(dtype.__name__):

                        """is source is none insert default value"""
                        if source_data_value is None:
                            self.json_data_transformed[destination_field_name] = dtype.__call__(
                                destination_mappings_json_object.get("default_value")
                            )

                        else:
                            """check if you have items to transform"""
                            if transform_data is not None:
                                """ check for invalid mask name """
                                if transform_data.get("transform_mask") not in list(self.look_up_mask.keys()):
                                    raise Exception(
                                        f"Specified Transform {transform_data.get('transform_mask')} is not available please select from following Options :{list(self.look_up_mask.keys())}")
                                else:
                                    mask_apply = self.look_up_mask.get(transform_data.get("transform_mask"))
                                    converted_dtype = dtype.__call__(source_data_value)
                                    mask = f'converted_dtype{mask_apply}'
                                    curated_value = eval(mask)
                                    self.json_data_transformed[destination_field_name] = curated_value

                            else:
                                self.json_data_transformed[destination_field_name] = dtype.__call__(source_data_value)

        return self.json_data_transformed

# %%
transformed_data = []
for item in json_Fact_df:
    helper = STTM(input_json=item)
    response = helper.get_transformed_data()
    transformed_data.append(response)
    print(response)
# Out:
# Streaming output truncated to the last 5000 lines.
# {'Date': '2009-02-25', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2009-03-30', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2009-05-09', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2009-05-10', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2009-05-18', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2009-06-21', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2009-09-07', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2009-09-13', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2009-09-17', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2009-09-17', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2009-12-28', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-01-15', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-02-14', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-02-15', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-03-19', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-03-22', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-04-01', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-04-19', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-04-24', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-04-24', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-04-25', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-04-26', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-06-03', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-07-07', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-07-08', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-07-15', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-08-05', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-08-25', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-09-19', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-10-26', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-10-28', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-10-31', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-11-09', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-11-28', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-12-10', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-12-19', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-12-23', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2010-12-27', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-01-09', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-01-14', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-01-19', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-02-02', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-02-05', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-02-17', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-02-18', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-03-03', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-03-12', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-03-21', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-03-23', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-04-25', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-05-24', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-05-27', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-06-02', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-06-05', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-06-15', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-06-22', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-06-27', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-07-01', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-07-02', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-07-22', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-07-23', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-08-23', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-09-05', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-09-05', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-09-11', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-09-23', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-09-25', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-09-26', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-10-24', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-12-10', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-12-13', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-12-18', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2011-12-27', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2012-01-15', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2012-02-11', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2012-02-27', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2012-03-08', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2012-03-18', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2012-03-31', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2012-05-16', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2012-05-21', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2012-06-19', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2012-07-08', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2012-07-17', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2012-09-22', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2012-10-07', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2012-11-15', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2012-12-19', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2013-01-17', 'PatientNumber': 273, 'Age': 81, 'RoutineTest': '0'}
# {'Date': '2013
 'PatientNumber': 274, 'Age': 89, 'RoutineTest': '0'}
# {'Date': '2019-12-30', 'PatientNumber': 274, 'Age': 89, 'RoutineTest': '0'}
# {'Date': '2005-01-02', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2005-01-30', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2005-03-03', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2005-03-09', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2005-03-12', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2005-04-30', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2005-07-17', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2005-07-17', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2005-08-29', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2005-09-02', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2005-09-15', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2005-09-16', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2005-09-29', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2005-12-19', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2005-12-21', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2006-02-04', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2006-03-17', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2006-03-18', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2006-03-30', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2006-04-08', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2006-04-16', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2006-06-30', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2006-07-05', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2006-07-27', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2006-08-18', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2006-08-19', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2006-09-20', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2006-10-07', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2006-12-08', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2006-12-15', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2006-12-17', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2006-12-19', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2006-12-28', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2007-02-17', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2007-03-02', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2007-03-27', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2007-05-19', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2007-05-21', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2007-05-24', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2007-05-30', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2007-06-09', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2007-08-01', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2007-08-14', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2007-08-15', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2007-09-25', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2007-09-27', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2007-10-03', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2007-11-01', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2007-11-04', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2007-11-07', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2007-12-17', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2008-01-15', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2008-01-17', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# {'Date': '2008-02-11', 'PatientNumber': 275, 'Age': 76, 'RoutineTest': '0'}
# ...
# {'Date': '2015-06-13', 'PatientNumber': 298, 'Age': 78, 'RoutineTest': '0'}
# {'Date': '2015-09-15', 'PatientNumber': 298, 'Age': 78, 'RoutineTest': '0'}
# {'Date': '2016-02-17', 'PatientNumber': 298, 'Age': 78, 'RoutineTest': '0'}
# {'Date': '2016-12-10', 'PatientNumber': 298, 'Age': 78, 'RoutineTest': '0'}
# {'Date': '2017-06-14', 'PatientNumber': 298, 'Age': 78, 'RoutineTest': '0'}
# {'Date': '2017-08-14', 'PatientNumber': 298, 'Age': 78, 'RoutineTest': '0'}
# {'Date': '2017-11-03', 'PatientNumber': 298, 'Age': 78, 'RoutineTest': '0'}
# {'Date': '2018-04-05', 'PatientNumber': 298, 'Age': 78, 'RoutineTest': '0'}
# {'Date': '2018-04-29', 'PatientNumber': 298, 'Age': 78, 'RoutineTest': '0'}
# {'Date': '2018-11-15', 'PatientNumber': 298, 'Age': 78, 'RoutineTest': '0'}
# {'Date': '2019-02-16', 'PatientNumber': 298, 'Age': 78, 'RoutineTest': '0'}
# {'Date': '2019-04-12', 'PatientNumber': 298, 'Age': 78, 'RoutineTest': '0'}
# {'Date': '2019-08-01', 'PatientNumber': 298, 'Age': 78, 'RoutineTest': '0'}
# {'Date': '2019-08-19', 'PatientNumber': 298, 'Age': 78, 'RoutineTest': '0'}
# {'Date': '2005-02-05', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2005-03-05', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2005-03-28', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2005-05-08', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2005-06-26', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2005-08-16', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2005-09-13', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2005-09-21', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2005-10-17', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2005-12-01', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2005-12-28', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2006-01-13', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2006-02-11', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2006-02-22', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2006-02-25', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2006-03-18', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2006-05-05', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2006-07-19', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2006-07-29', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2006-08-15', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2006-08-17', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2006-08-20', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2006-08-28', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2006-09-17', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2006-09-20', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2006-10-17', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2006-11-20', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2006-12-24', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2007-01-13', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2007-02-23', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2007-04-30', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2007-05-28', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2007-08-12', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2007-08-15', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2007-09-06', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2007-09-22', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2007-12-17', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2008-03-14', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2008-04-20', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2008-06-20', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2008-09-14', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2008-09-22', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '2008-10-15', 'PatientNumber': 300, 'Age': 90, 'RoutineTest': '0'}
# {'Date': '